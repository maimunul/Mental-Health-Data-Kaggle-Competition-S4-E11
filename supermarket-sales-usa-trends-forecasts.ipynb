# %% [markdown]
# <a href="https://www.kaggle.com/code/maimunulkjisan/supermarket-sales-usa-trends-forecasts?scriptVersionId=216509010" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 🚀 **Exploratory Data Analysis (EDA) and Predicting Future Sales** 🚀
#
# Welcome to this notebook, where we explore a retail dataset spanning **4 years**. The goal is to perform an in-depth analysis of sales trends, shipping durations, and customer behaviors, followed by forecasting the next **7 days of sales**. This notebook highlights key insights using interactive visualizations and predictive modeling. Let’s dive in!
#
# ## 📌 Introduction
# In this notebook, we will:
#
# 🧹 Clean and preprocess the data for meaningful analysis.
#
# 🔎 Perform an in-depth Exploratory Data Analysis (EDA) to understand trends and patterns.
#
# 📈 Visualize insights through interactive and intuitive graphs.

# %% [markdown]
# ## 📋 **Dataset Description**
#
# | **Column Name**      | **Description**                                                                                  | **Example Value**                          |
# |-----------------------|--------------------------------------------------------------------------------------------------|--------------------------------------------|
# | `Order ID`           | Unique identifier for each order.                                                               | CA-2015-103800                             |
# | `Order Date`         | The date when the order was placed.                                                             | 2015-01-03                                 |
# | `Ship Date`          | The date when the order was shipped.                                                            | 2015-01-07                                 |
# | `Ship Mode`          | The shipping method used for delivery.                                                          | Standard Class                             |
# | `Customer ID`        | Unique identifier for each customer.                                                            | DP-13000                                   |
# | `Customer Name`      | Name of the customer who placed the order.                                                      | Darren Powers                              |
# | `Segment`            | The market segment the customer belongs to.                                                    | Consumer                                   |
# | `Country`            | The country where the order was placed.                                                        | United States                              |
# | `City`               | The city where the order was placed.                                                           | Houston                                    |
# | `State`              | The state where the order was placed.                                                          | Texas                                      |
# | `Postal Code`        | The postal code for the shipping address.                                                      | 77095                                      |
# | `Region`             | The region where the order originated.                                                         | Central                                    |
# | `Product ID`         | Unique identifier for each product.                                                            | OFF-PA-10000174                            |
# | `Category`           | The main category of the product.                                                              | Office Supplies                            |
# | `Sub-Category`       | The sub-category of the product.                                                               | Paper                                      |
# | `Product Name`       | The name or description of the product.                                                        | Message Book, Wirebound...                 |
# | `Sales`              | Total sales amount for the order.                                                              | 16.448                                     |

# %% [markdown]
# # ⚙️ Data Import and Cleaning
# 🔍 In this section, we import the dataset, clean missing values, and preprocess date columns for time-series analysis.
# Code Steps:
#
# Import necessary libraries.
# Load the dataset.
# Handle missing values in the Postal Code column.
# Convert Order Date and Ship Date into datetime format.
# Sort data by Order Date.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
df = pd.read_csv("/kaggle/input/sales-forecasting/train.csv", index_col='Row ID')
print(df.info())

# Convert dates and clean data
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d/%m/%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%d/%m/%Y')
df.sort_values(by=['Order Date'], ascending=True, inplace=True)
df.set_index('Order Date', inplace =True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9800 entries, 1 to 9800
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   object
#  1   Order Date     9800 non-null   object
#  2   Ship Date      9800 non-null   object
#  3   Ship Mode      9800 non-null   object
#  4   Customer ID    9800 non-null   object
#  5   Customer Name  9800 non-null   object
#  6   Segment        9800 non-null   object
#  7   Country        9800 non-null   object
#  8   City           9800 non-null   object
#  9   State          9800 non-null   object
#  10  Postal Code    9789 non-null   float64
#  11  Region         9800 non-null   object
#  12  Product ID     9800 non-null   object
#  13  Category       9800 non-null   object
#  14  Sub-Category   9800 non-null   object
#  15  Product Name   9800 non-null   object
#  16  Sales          9800 non-null   float64
# dtypes: float64(2), object(15)
# memory usage: 1.3+ MB
# None

# %%
df.head(5)
# Out:
#                   Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2015-01-03  CA-2015-103800 2015-01-07  Standard Class    DP-13000
# 2015-01-04  CA-2015-112326 2015-01-08  Standard Class    PO-19195
# 2015-01-04  CA-2015-112326 2015-01-08  Standard Class    PO-19195
# 2015-01-04  CA-2015-112326 2015-01-08  Standard Class    PO-19195
# 2015-01-05  CA-2015-141817 2015-01-12  Standard Class    MB-18085
#
#             Customer Name      Segment        Country          City  \
# Order Date
# 2015-01-03  Darren Powers     Consumer  United States       Houston
# 2015-01-04  Phillina Ober  Home Office  United States    Naperville
# 2015-01-04  Phillina Ober  Home Office  United States    Naperville
# 2015-01-04  Phillina Ober  Home Office  United States    Naperville
# 2015-01-05     Mick Brown     Consumer  United States  Philadelphia
#
#                    State  Postal Code   Region       Product ID  \
# Order Date
# 2015-01-03         Texas      77095.0  Central  OFF-PA-10000174
# 2015-01-04      Illinois      60540.0  Central  OFF-BI-10004094
# 2015-01-04      Illinois      60540.0  Central  OFF-ST-10002743
# 2015-01-04      Illinois      60540.0  Central  OFF-LA-10003223
# 2015-01-05  Pennsylvania      19143.0     East  OFF-AR-10003478
#
#                    Category Sub-Category  \
# Order Date
# 2015-01-03  Office Supplies        Paper
# 2015-01-04  Office Supplies      Binders
# 2015-01-04  Office Supplies      Storage
# 2015-01-04  Office Supplies       Labels
# 2015-01-05  Office Supplies          Art
#
#                                                  Product Name    Sales
# Order Date
# 2015-01-03  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448
# 2015-01-04         GBC Standard Plastic Binding Systems Combs    3.540
# 2015-01-04                      SAFCO Boltless Steel Shelving  272.736
# 2015-01-04                                          Avery 508   11.784
# 2015-01-05  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536

# %% [markdown]
# # 🛠 Handling Missing Values
# We checked for missing values and filled the Postal Code column with the postal code for Burlington City.

# %%
df.isnull().sum()
# Out:
# Order ID          0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df['Postal Code'].fillna(27217.0, inplace=True)  # Fill missing Postal Code values

# %% [markdown]
# ### here null value available in Postal Code Burlington city, so here filling those null value with burlington postal code availbale in dataset

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
# **In this section, we visualize trends and patterns in the dataset to gain insights into sales, shipping, and customer behaviors.**

# %% [markdown]
# # 📌 Sales by Category
# **Visualization:** A pie chart showing the total sales across different product categories.
#
# 👉 This helps identify which category contributes the most to sales.

# %%
# Sales by category
sales_by_category = df.groupby('Category')['Sales'].sum().reset_index()
fig1 = px.pie(sales_by_category, names='Category', values='Sales', title='Sales by Category', color='Category')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ad6a0c42-ed60-49b3-96d9-14fe6ffdd383" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad6a0c42-ed60-49b3-96d9-14fe6ffdd383")) {                    Plotly.newPlot(                        "ad6a0c42-ed60-49b3-96d9-14fe6ffdd383",                        [{"customdata":[["Furniture"],["Office Supplies"],["Technology"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Category=%{customdata[0]}\u003cbr\u003eSales=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Furniture","Office Supplies","Technology"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96"]},"name":"","showlegend":true,"values":[728658.5757,705422.334,827455.873],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatter ...

# %% [markdown]
# # 🌆 Sales by City (Top 10 Cities)
# **Visualization:** A pie chart highlighting sales in the top 10 cities.
#
# 👉 This gives insights into geographic sales distribution.

# %%
# Top 10 cities by sales
sales_by_city = df.groupby('City')['Sales'].sum().sort_values(ascending=False).reset_index()
top_10_sales_by_city = sales_by_city.head(10)
fig2 = px.pie(top_10_sales_by_city, names='City', values='Sales', title='Total Sales by City (Top 10)', color='City')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="661c2d55-a161-4ddf-9bef-1d2ac84d0214" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("661c2d55-a161-4ddf-9bef-1d2ac84d0214")) {                    Plotly.newPlot(                        "661c2d55-a161-4ddf-9bef-1d2ac84d0214",                        [{"customdata":[["New York City"],["Los Angeles"],["Seattle"],["San Francisco"],["Philadelphia"],["Houston"],["Chicago"],["San Diego"],["Jacksonville"],["Detroit"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"City=%{customdata[0]}\u003cbr\u003eSales=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["New York City","Los Angeles","Seattle","San Francisco","Philadelphia","Houston","Chicago","San Diego","Jacksonville","Detroit"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52"]},"name":"","showlegend":true,"values":[252462.547,173420.181,116106.322,109041.12,108841.749,63956.1428,47820.133,47521.029,44713.183,42446.944],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %% [markdown]
# # 🚚 Distribution of Shipping Duration
# **Visualization:** A bar chart showing the distribution of shipping durations.
#
# 👉 This indicates the frequency of different shipping durations.

# %%
df.index = pd.to_datetime(df.index)
df['Shipping Duration'] = (df['Ship Date'] - df.index).dt.days
shipping_duration_counts = df['Shipping Duration'].value_counts().sort_index()

import plotly.express as px

fig = px.bar(
    x=shipping_duration_counts.index, 
    y=shipping_duration_counts.values, 
    labels={'x': 'Shipping Duration (days)', 'y': 'Frequency'}, 
    title='Distribution of Shipping Duration',
    text=shipping_duration_counts.values, 
)

fig.update_traces(marker_color='teal', textposition='outside') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4452a002-d61f-41e3-845d-e997c2b643b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4452a002-d61f-41e3-845d-e997c2b643b4")) {                    Plotly.newPlot(                        "4452a002-d61f-41e3-845d-e997c2b643b4",                        [{"alignmentgroup":"True","hovertemplate":"Shipping Duration (days)=%{x}\u003cbr\u003eFrequency=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"teal","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[514.0,363.0,1295.0,978.0,2718.0,2147.0,1170.0,615.0],"textposition":"outside","x":[0,1,2,3,4,5,6,7],"xaxis":"x","y":[514,363,1295,978,2718,2147,1170,615],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"so ...

# %% [markdown]
# # 🌍 Sales by Region
# **Visualization:**  A pie chart of total sales by region.
#
# 👉 This provides a clear view of which regions perform best.

# %%
# Sales by region
sales_by_region = df.groupby('Region')['Sales'].sum().reset_index()
fig4 = px.pie(sales_by_region, names='Region', values='Sales', title='Total Sales by Region', color='Region')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9cb82a6c-22c8-43f9-91ae-00ca8e966caf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cb82a6c-22c8-43f9-91ae-00ca8e966caf")) {                    Plotly.newPlot(                        "9cb82a6c-22c8-43f9-91ae-00ca8e966caf",                        [{"customdata":[["Central"],["East"],["South"],["West"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Region=%{customdata[0]}\u003cbr\u003eSales=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Central","East","South","West"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa"]},"name":"","showlegend":true,"values":[492646.9132,669518.726,389151.45900000003,710219.6845],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type": ...

# %% [markdown]
# ### Company must be focus on increase sales in **South and Central** region

# %% [markdown]
# # 🛒 Sales by Sub-Category
# **Visualization:** A pie chart for sales by sub-category.
#
# 👉 This helps understand the demand for specific products.

# %%
# Sales by sub-category
sales_by_sub_category = df.groupby('Sub-Category')['Sales'].sum().reset_index()
sales_by_sub_category = sales_by_sub_category.sort_values(by='Sales', ascending=False)
fig5 = px.pie(sales_by_sub_category, names='Sub-Category', values='Sales', title='Total Sales by Sub-Category', color='Sub-Category')
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7e4e24f5-329f-43ae-82b5-ee2cc4ed7cf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e4e24f5-329f-43ae-82b5-ee2cc4ed7cf9")) {                    Plotly.newPlot(                        "7e4e24f5-329f-43ae-82b5-ee2cc4ed7cf9",                        [{"customdata":[["Phones"],["Chairs"],["Storage"],["Tables"],["Binders"],["Machines"],["Accessories"],["Copiers"],["Bookcases"],["Appliances"],["Furnishings"],["Paper"],["Supplies"],["Art"],["Envelopes"],["Labels"],["Fasteners"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sub-Category=%{customdata[0]}\u003cbr\u003eSales=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Phones","Chairs","Storage","Tables","Binders","Machines","Accessories","Copiers","Bookcases","Appliances","Furnishings","Paper","Supplies","Art","Envelopes","Labels","Fasteners"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52","#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692"]},"name":"","showlegend":true,"values":[327782.448,322822.731,219343.392,202810.628,200028.785,189238.631,164186.7,146248.094,113813.1987,104618.403,89212.018,76828.304,46420.308,26705.41,16128.046,12347.726,3001.96],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"] ...

# %% [markdown]
# # 👩‍💼 Top 10 Customers by Total Sales
# **Visualization:** A pie chart showing the top 10 customers contributing to sales.
#
# 👉 This analysis identifies high-value customers.

# %%
# Top 10 customers by sales
sales_by_customer = df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).reset_index()
top_10_sales_by_customer = sales_by_customer.head(10)
fig6 = px.pie(top_10_sales_by_customer, names='Customer Name', values='Sales', title='Top 10 Customers by Total Sales', color='Customer Name')
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="25c2e3a7-202c-4e01-83f2-d9768e99a56d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25c2e3a7-202c-4e01-83f2-d9768e99a56d")) {                    Plotly.newPlot(                        "25c2e3a7-202c-4e01-83f2-d9768e99a56d",                        [{"customdata":[["Sean Miller"],["Tamara Chand"],["Raymond Buch"],["Tom Ashbrook"],["Adrian Barton"],["Ken Lonsdale"],["Sanjit Chand"],["Hunter Lopez"],["Sanjit Engle"],["Christopher Conant"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Customer Name=%{customdata[0]}\u003cbr\u003eSales=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Sean Miller","Tamara Chand","Raymond Buch","Tom Ashbrook","Adrian Barton","Ken Lonsdale","Sanjit Chand","Hunter Lopez","Sanjit Engle","Christopher Conant"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52"]},"name":"","showlegend":true,"values":[25043.05,19052.218,15117.339,14595.62,14473.571,14175.229,14142.334,12873.297999999999,12209.438,12129.072],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{" ...

# %% [markdown]
# # ⏱ Average Shipping Duration by Sub-Category
# **Visualization:** A bar chart displaying average shipping duration for each product sub-category.

# %%
# Average shipping duration by sub-category
avg_shipping_duration_by_sub_category = df.groupby('Sub-Category')['Shipping Duration'].mean().reset_index()
fig = px.bar(avg_shipping_duration_by_sub_category, x='Sub-Category', y='Shipping Duration', title='Average Shipping Duration by Sub-Category', labels={'Shipping Duration': 'Average Shipping Duration (Days)', 'Sub-Category': 'Sub-Category'}, color='Sub-Category', text='Shipping Duration')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="722eb838-95be-4027-bf9d-22a486ee5ab2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("722eb838-95be-4027-bf9d-22a486ee5ab2")) {                    Plotly.newPlot(                        "722eb838-95be-4027-bf9d-22a486ee5ab2",                        [{"alignmentgroup":"True","hovertemplate":"Sub-Category=%{x}\u003cbr\u003eAverage Shipping Duration (Days)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accessories","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Accessories","offsetgroup":"Accessories","orientation":"v","showlegend":true,"text":[3.884920634920635],"textposition":"auto","x":["Accessories"],"xaxis":"x","y":[3.884920634920635],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=%{x}\u003cbr\u003eAverage Shipping Duration (Days)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Appliances","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Appliances","offsetgroup":"Appliances","orientation":"v","showlegend":true,"text":[3.991285403050109],"textposition":"auto","x":["Appliances"],"xaxis":"x","y":[3.991285403050109],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=%{x}\u003cbr\u003eAverage Shipping Duration (Days)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Art","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Art","offsetgroup":"Art","orientation":"v","showlegend":true,"text":[4.057324840764331],"textposition":"auto","x":["Art"],"xaxis":"x","y":[4.057324840764331],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=%{x}\u003cbr\u003eAverage Shipping Duration (Days)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Binders","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Binders","offsetgroup":"Binders","orientation":"v","showlegend":true,"text":[4.0328418230563],"textposition":"auto","x":["Binders"],"xaxis":"x","y":[4.0328418230563],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=%{x}\u003cbr\u003eAverage Shipping Duration (Days)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bookcases","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Bookcases","offsetgroup":"Bookcases","orientation":"v","showlegend":true,"text":[3.814159292035398],"textposition":"auto","x":["Bookcases"],"xaxis":"x","y":[3.814159292035398],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=%{x}\u003cbr\u003eAverage Shipping Duration (Days)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chairs","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Chairs","offsetgroup":"Chairs","orientation":"v","showlegend":true,"text":[3.9028006589785833],"textposition":"auto","x":["Chairs"],"xaxis":"x","y":[3.9028006589785833],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=%{x}\u003cbr\u003eAverage Shipping Duration (Days)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Copiers","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Copiers","offsetgroup":"Copiers","orientation":"v","showlegend":true,"text":[3.6363636363636362],"textposition":"auto","x":["Copiers"],"xaxis":"x","y":[3.6363636363636362],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=%{x}\u003cbr\u003eAverage Shipping Duration (Days)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Envelopes","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Envelopes","offsetgroup":"Envelopes","orientation":"v","showlegend":true,"text":[4.008064516129032],"textposition":"auto","x":["Envelo ...

# %% [markdown]
# # 🚢 Shipping Modes Used
# **Visualization:** A bar chart of the count of different shipping modes.

# %%
# Shipping modes count
ship_mode_counts = df['Ship Mode'].value_counts().reset_index()
ship_mode_counts.columns = ['Ship Mode', 'Count']
fig = px.bar(ship_mode_counts, x='Ship Mode', y='Count', title='Count of Ship Modes Used', labels={'Ship Mode': 'Shipping Mode', 'Count': 'Number of Orders'}, color='Ship Mode', text='Count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d922cb75-fe01-492f-a46a-c7b454b849be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d922cb75-fe01-492f-a46a-c7b454b849be")) {                    Plotly.newPlot(                        "d922cb75-fe01-492f-a46a-c7b454b849be",                        [{"alignmentgroup":"True","hovertemplate":"Shipping Mode=%{x}\u003cbr\u003eNumber of Orders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Standard Class","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Standard Class","offsetgroup":"Standard Class","orientation":"v","showlegend":true,"text":[5859.0],"textposition":"auto","x":["Standard Class"],"xaxis":"x","y":[5859],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shipping Mode=%{x}\u003cbr\u003eNumber of Orders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Second Class","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Second Class","offsetgroup":"Second Class","orientation":"v","showlegend":true,"text":[1902.0],"textposition":"auto","x":["Second Class"],"xaxis":"x","y":[1902],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shipping Mode=%{x}\u003cbr\u003eNumber of Orders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"First Class","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"First Class","offsetgroup":"First Class","orientation":"v","showlegend":true,"text":[1501.0],"textposition":"auto","x":["First Class"],"xaxis":"x","y":[1501],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Shipping Mode=%{x}\u003cbr\u003eNumber of Orders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Same Day","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Same Day","offsetgroup":"Same Day","orientation":"v","showlegend":true,"text":[538.0],"textposition":"auto","x":["Same Day"],"xaxis":"x","y":[538],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"color ...

# %% [markdown]
# # 📊 Sales by Segment
# **Visualization:** A donut chart of total sales by customer segment.

# %%
# Sales by segment
sales_by_segment = df.groupby('Segment')['Sales'].sum().reset_index()
fig = px.pie(sales_by_segment, names='Segment', values='Sales', title='Sales by Segment', color='Segment', hole=0.3)
fig.update_traces(hovertemplate='Segment: %{label}<br>Sales: $%{value:,.2f}<extra></extra>', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5d920df6-6214-4f10-82eb-74d16c73f3e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d920df6-6214-4f10-82eb-74d16c73f3e1")) {                    Plotly.newPlot(                        "5d920df6-6214-4f10-82eb-74d16c73f3e1",                        [{"customdata":[["Consumer"],["Corporate"],["Home Office"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Segment: %{label}\u003cbr\u003eSales: $%{value:,.2f}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Consumer","Corporate","Home Office"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96"]},"name":"","showlegend":true,"values":[1148060.531,688494.0748000001,424982.1769],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar" ...

# %% [markdown]
# # Finding Top 10 Customers by Subcategory Based on Sales
#
# To identify the top 10 customers who buy the most in each subcategory based on sales, we can follow these steps:
#
# 1. **Group the data by 'Customer Name' and 'Sub-Category'**: This will allow us to calculate the total sales for each customer within each subcategory.
# 2. **Sort the data by 'Sales' in descending order**: This ensures that the customers with the highest sales come first in each subcategory.
# 3. **Select the top 10 customers**: For each subcategory, we select the top 10 customers based on their sales.

# %%
sales_by_customer_subcategory = df.groupby(['Customer Name', 'Sub-Category'])['Sales'].sum().reset_index()
top_10_customers_subcategory = sales_by_customer_subcategory.sort_values(['Sub-Category', 'Sales'], ascending=[True, False])
top_10_customers_subcategory = top_10_customers_subcategory.groupby('Sub-Category').head(10)
fig = px.bar(
    top_10_customers_subcategory, 
    x='Customer Name', 
    y='Sales', 
    color='Sub-Category', 
    title='Top 10 Customers by Subcategory Based on Sales',
    labels={'Customer Name': 'Customer Name', 'Sales': 'Total Sales'},
    color_discrete_sequence=px.colors.qualitative.Set1
)

fig.update_layout(
    xaxis_tickangle=-45,
    xaxis={'categoryorder': 'total ascending'}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f6d5e526-c127-4ccc-96da-71f81f1ef428" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6d5e526-c127-4ccc-96da-71f81f1ef428")) {                    Plotly.newPlot(                        "f6d5e526-c127-4ccc-96da-71f81f1ef428",                        [{"alignmentgroup":"True","hovertemplate":"Sub-Category=Accessories\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accessories","marker":{"color":"rgb(228,26,28)","pattern":{"shape":""}},"name":"Accessories","offsetgroup":"Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Kelly Collister","Helen Wasserman","Peter McVee","Rick Hansen","Natalie Fritzler","Thomas Boland","Karen Bern","Anna H\u00e4berlin","Bill Eplett","Jim Kriz"],"xaxis":"x","y":[3795.2999999999997,2605.9900000000002,2441.886,2309.65,2259.81,2249.91,2015.35,1979.7,1928.78,1747.78],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Appliances\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Appliances","marker":{"color":"rgb(55,126,184)","pattern":{"shape":""}},"name":"Appliances","offsetgroup":"Appliances","orientation":"v","showlegend":true,"textposition":"auto","x":["Rick Wilson","Annie Thurman","Justin Deggeller","Jonathan Doherty","Frank Carlisle","Robert Waldorf","Anthony Jacobs","Doug Jacobs","Jamie Kunitz","Fred Chung"],"xaxis":"x","y":[2981.006,2768.24,2504.74,2104.55,2089.158,2016.7140000000002,1737.18,1704.56,1702.12,1640.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Art\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Art","marker":{"color":"rgb(77,175,74)","pattern":{"shape":""}},"name":"Art","offsetgroup":"Art","orientation":"v","showlegend":true,"textposition":"auto","x":["Brendan Sweed","Brenda Bowman","Nicole Hansen","Paul Gonzalez","Raymond Buch","Kelly Andreada","Marc Crier","Rob Haberlin","Corey Roper","Emily Phan"],"xaxis":"x","y":[1146.424,422.664,421.42,403.11,378.776,338.27000000000004,309.71999999999997,293.76,289.2,269.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Binders\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Binders","marker":{"color":"rgb(152,78,163)","pattern":{"shape":""}},"name":"Binders","offsetgroup":"Binders","orientation":"v","showlegend":true,"textposition":"auto","x":["Sanjit Chand","Adrian Barton","Christopher Martinez","Andy Reiter","Jane Waco","Dennis Pardue","Adam Bellavance","Pete Kriz","Shirley Daniels","Gary Hwang"],"xaxis":"x","y":[11468.166000000001,11068.91,8377.222,5489.08,5083.96,4772.516,4404.215999999999,4397.9839999999995,3838.41,3279.204],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Bookcases\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bookcases","marker":{"color":"rgb(255,127,0)","pattern":{"shape":""}},"name":"Bookcases","offsetgroup":"Bookcases","orientation":"v","showlegend":true,"textposition":"auto","x":["Peter Fuller","Quincy Jones","Greg Tran","Maribeth Schnelling","Tracy Blumstein","Anna Gayman","Nora Paige","Jack O'Briant","Tom Stivers","Shahid Collister"],"xaxis":"x","y":[6232.624,4404.9,4007.84,3406.664,3083.43,2396.2656,2154.9,2122.545,1889.8,1628.82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Chairs\u003cbr\u003eCustomer Name=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u00 ...
